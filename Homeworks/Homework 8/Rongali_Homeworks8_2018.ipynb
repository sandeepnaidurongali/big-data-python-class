# %%
import os
import pandas as pd
import numpy as np
from numpy import *

# %%
# !type ATT_dataset_small.csv
# Out:
# Region,Data Request type
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# OHIO,WIRELESS
# INDIANA,WIRELESS
# INDIANA,WIRELESS
# INDIANA,WIRELESS
# INDIANA,WIRELESS
# INDIANA,WIRELESS
# INDIANA,WIRELESS
# INDIANA,WIRELESS
# INDIANA,WIRELESS
# INDIANA,WIRELESS
# INDIANA,WIRELESS
# INDIANA,WIRELESS
# INDIANA,WIRELESS
# INDIANA,WIRELESS
# INDIANA,WIRELESS
# NEWYORK,DirecTV
# NEWYORK,DirecTV
# NEWYORK,DirecTV
# NEWYORK,DirecTV
# ALABAMA,WIRELESS
# ALABAMA,WIRELESS
# NEWYORK,U-VERSE
# NEWYORK,U-VERSE
# NEWYORK,U-VERSE
# TEXAS,WIRELINES
# TEXAS,WIRELINES
# TEXAS,WIRELINES
# NEWYORK,U-VERSE
# CALIFORNIA,WLL
# CALIFORNIA,WLL
# CALIFORNIA,WLL
# ALABAMA,WIRELESS
# ALABAMA,WIRELESS
# ALABAMA,WIRELESS
# NEWYORK,CB(SynergyDTV+3rdPartyWireline)
# ...

# %%
data = pd.read_table("ATT_dataset_small.csv", sep=',', header=None)
data
# Out:
#             0                  1
# 0      Region  Data Request type
# 1        OHIO           WIRELESS
# 2        OHIO           WIRELESS
# 3        OHIO           WIRELESS
# 4        OHIO           WIRELESS
# 5        OHIO           WIRELESS
# 6        OHIO           WIRELESS
# 7        OHIO           WIRELESS
# 8        OHIO           WIRELESS
# 9        OHIO           WIRELESS
# 10       OHIO           WIRELESS
# 11       OHIO           WIRELESS
# 12       OHIO           WIRELESS
# 13       OHIO           WIRELESS
# 14       OHIO           WIRELESS
# 15       OHIO           WIRELESS
# 16       OHIO           WIRELESS
# 17       OHIO           WIRELESS
# 18       OHIO           WIRELESS
# 19    INDIANA           WIRELESS
# 20    INDIANA           WIRELESS
# 21    INDIANA           WIRELESS
# 22    INDIANA           WIRELESS
# 23    INDIANA           WIRELESS
# 24    INDIANA           WIRELESS
# 25    INDIANA           WIRELESS
# 26    INDIANA           WIRELESS
# ...

# %%
data = genfromtxt('ATT_dataset_small.csv',skip_header=1, delimiter=',', dtype=None,usecols=arange(0,2))
temp=np.array(data)
temp
# Out:
# C:\Users\Sandeep\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   """Entry point for launching an IPython kernel.
# array([['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['OHIO', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
#        ['INDIANA', 'WIRELESS'],
# ...

# %% [markdown]
# # Analyze the ATT dataset with Aprioior algorithm

# %% [markdown]
# I have taken everything form only one article[1] and I have mentioned it below.Apriori uses a breadth-first search strategy to count the support of itemsets and uses a candidate generation function which exploits the downward closure property of support.The Apriori algorithm principle says that if an itemset is frequent, then all of its subsets are frequent.this means that if {0,1} is frequent, then {0} and {1} have to be frequent. The rule turned around says that if an itemset is infrequent, then its supersets are also infrequent. We first need to find the frequent itemsets, and then we can find association rules.Interesting relationships can take two forms: frequent item sets or association rules. Frequent item sets are a collection of items that frequently occur together. The second way to view interesting relationships is association rules. Association rules suggest that a strong relationship exists between two items. With the frequent item sets and association rules, retailers have a much better understanding of their customers. Another example is search terms from a search engine.General approach to the Apriori algorithm Collect: Any method. Prepare: Any data type will work as we’re storing sets. Analyze: Any method. Train: Use the Apriori algorithm to find frequent itemsets. Test: Doesn’t apply. Use: This will be used to find frequent itemsets and association rules between items.The way to find frequent itemsets is the Apriori algorithm. The Apriori algorithm needs a minimum support level as an input and a data set. The algorithm will generate a list of all candidate itemsets with one item. The transaction data set will then be scanned to see which sets meet the minimum support level. Sets that don’t meet the minimum support level will get tossed out. The remaining sets will then be combined to make itemsets with two elements. Again, the transaction dataset will be scanned and itemsets not meeting the minimum support level will get tossed. This procedure will be repeated until all sets are tossed out.It creates C1 .C1 is a candidate itemset of size one. In the Apriori algorithm, we create C1, and then we’ll scan the dataset to see if these one itemsets meet our minimum support requirements. The itemsets that do meet our minimum requirements become L1. L1 then gets combined to become C2 and C2 will get filtered to become L2. Frozensets are sets that are frozen, which means they’re immutable; you can’t change them. You need to use the type frozenset instead of set because you’ll later use these sets as the key in a dictionary. You can’t create a set of just one integer in Python. It needs to be a list (try it out). That’s why you create a list of single-item lists. Finally, you sort the list and then map every item in the list to frozenset() and return this list of frozensets

# %%
def createSample(dataSet):
    Sample = []
    for transaction in dataSet:
        for item in transaction:
            if not [item] in Sample:
                Sample.append([item])
                
    Sample.sort()
    return list(map(frozenset, Sample))#use frozen set so we can use it as a key in a dict

# %%
Sample = createSample(temp)
Sample
# Out:
# [frozenset({'ALABAMA'}),
#  frozenset({'CALIFORNIA'}),
#  frozenset({'CB(SynergyDTV+3rdPartyWireline)'}),
#  frozenset({'CB(Wireline+SynergyDTV)'}),
#  frozenset({'CB-U-VERSE'}),
#  frozenset({'CB-WIRELINE'}),
#  frozenset({'DigitalLife'}),
#  frozenset({'DirecTV'}),
#  frozenset({'GEORGIA'}),
#  frozenset({'INDIANA'}),
#  frozenset({'MISSOURI'}),
#  frozenset({'NEWYORK'}),
#  frozenset({'OHIO'}),
#  frozenset({'OPENPORTAL'}),
#  frozenset({'PENSELVANIYA'}),
#  frozenset({'TEXAS'}),
#  frozenset({'U-VERSE'}),
#  frozenset({'Unified(Uverse+DTV)'}),
#  frozenset({'Unified(Uverse+Wireless)'}),
#  frozenset({'Unified(Uverse+Wireless+DTV)'}),
#  frozenset({'Unified(WLL+DTV)'}),
#  frozenset({'Unified(WLL+Wireless)'}),
#  frozenset({'Unified(WLL+Wireless+DTV)'}),
#  frozenset({'Unified(Wireless+DTV)'}),
#  frozenset({'WIRELESS'}),
#  frozenset({'WIRELINES'}),
#  frozenset({'WLL'})]

# %% [markdown]
# This function takes three arguments: a dataset, Sample, a list of candidate sets, and minSupport, which is the minimum support you’re interested in. This is the function you’ll use to generate L1 from Sample. Additionally, this function returns a dictionary with support values.

# %%
def scanD(D, Ck, minSupport):
    ssCnt = {}
    for tid in D:
        for can in Ck:
            if can.issubset(tid):
                if not can in ssCnt: ssCnt[can]=1
                else: ssCnt[can] += 1
    numItems = float(len(D))
    retList = []
    supportData = {}
    for key in ssCnt:
        support = ssCnt[key]/numItems
        if support >= minSupport:
            retList.insert(0,key)
        supportData[key] = support
    return retList, supportData

# %%
D = list(map(set,temp))
D
# Out:
# [{'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'OHIO', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'INDIANA', 'WIRELESS'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'DirecTV', 'NEWYORK'},
#  {'ALABAMA', 'WIRELESS'},
# ...

# %%
L1,suppDat0 = scanD(D,Sample,0.01)
L1
# Out:
# [frozenset({'DirecTV'}),
#  frozenset({'CB-WIRELINE'}),
#  frozenset({'U-VERSE'}),
#  frozenset({'CB-U-VERSE'}),
#  frozenset({'GEORGIA'}),
#  frozenset({'Unified(Uverse+DTV)'}),
#  frozenset({'WIRELESS'}),
#  frozenset({'INDIANA'}),
#  frozenset({'CALIFORNIA'}),
#  frozenset({'Unified(Wireless+DTV)'}),
#  frozenset({'TEXAS'}),
#  frozenset({'CB(SynergyDTV+3rdPartyWireline)'}),
#  frozenset({'MISSOURI'}),
#  frozenset({'OHIO'}),
#  frozenset({'NEWYORK'}),
#  frozenset({'WIRELINES'}),
#  frozenset({'PENSELVANIYA'}),
#  frozenset({'Unified(Uverse+Wireless+DTV)'}),
#  frozenset({'ALABAMA'}),
#  frozenset({'WLL'})]

# %% [markdown]
# The main function is apriori(); it calls aprioriGen() to create candidate itemsets: Ck. The function aprioriGen() will take a list of frequent itemsets, Lk, and the size of the itemsets, k, to produce Ck. For example, it will take the itemsets {0}, {1}, {2} and so on and produce {0,1} {0,2}, and {1,2}. The sets are combined using the set union, which is the | symbol in Python.

# %%
def aprioriGen(Lk, k): #creates Ck
    retList = []
    lenLk = len(Lk)
    for i in range(lenLk):
        for j in range(i+1, lenLk): 
            L1 = list(Lk[i])[:k-2]; L2 = list(Lk[j])[:k-2]
            L1.sort(); L2.sort()
            if L1==L2: #if first k-2 elements are equal
                retList.append(Lk[i] | Lk[j]) #set union
    return retList

# %%
def apriori(dataSet, minSupport = 0.1):
    C1 = createC1(dataSet)
    D = list(map(set, dataSet))
    L1, supportData = scanD(D, C1, minSupport)
    L = [L1]
    k = 2
    while (len(L[k-2]) > 0):
        Ck = aprioriGen(L[k-2], k)
        Lk, supK = scanD(D, Ck, minSupport)#scan DB to get Lk
        supportData.update(supK)
        L.append(Lk)
        k += 1
    return L, supportData

# %%
L,suppData = apriori(temp)
L
# Out:
# [[frozenset({'DirecTV'}),
#   frozenset({'U-VERSE'}),
#   frozenset({'WIRELESS'}),
#   frozenset({'TEXAS'}),
#   frozenset({'MISSOURI'}),
#   frozenset({'NEWYORK'}),
#   frozenset({'WIRELINES'}),
#   frozenset({'PENSELVANIYA'}),
#   frozenset({'ALABAMA'})],
#  [frozenset({'NEWYORK', 'WIRELESS'})],
#  []]

# %%
L[1]
# Out:
# [frozenset({'NEWYORK', 'WIRELESS'})]

# %%
L[0]
# Out:
# [frozenset({'DirecTV'}),
#  frozenset({'U-VERSE'}),
#  frozenset({'WIRELESS'}),
#  frozenset({'TEXAS'}),
#  frozenset({'MISSOURI'}),
#  frozenset({'NEWYORK'}),
#  frozenset({'WIRELINES'}),
#  frozenset({'PENSELVANIYA'}),
#  frozenset({'ALABAMA'})]

# %%
aprioriGen(L[0],2)
# Out:
# [frozenset({'DirecTV', 'U-VERSE'}),
#  frozenset({'DirecTV', 'WIRELESS'}),
#  frozenset({'DirecTV', 'TEXAS'}),
#  frozenset({'DirecTV', 'MISSOURI'}),
#  frozenset({'DirecTV', 'NEWYORK'}),
#  frozenset({'DirecTV', 'WIRELINES'}),
#  frozenset({'DirecTV', 'PENSELVANIYA'}),
#  frozenset({'ALABAMA', 'DirecTV'}),
#  frozenset({'U-VERSE', 'WIRELESS'}),
#  frozenset({'TEXAS', 'U-VERSE'}),
#  frozenset({'MISSOURI', 'U-VERSE'}),
#  frozenset({'NEWYORK', 'U-VERSE'}),
#  frozenset({'U-VERSE', 'WIRELINES'}),
#  frozenset({'PENSELVANIYA', 'U-VERSE'}),
#  frozenset({'ALABAMA', 'U-VERSE'}),
#  frozenset({'TEXAS', 'WIRELESS'}),
#  frozenset({'MISSOURI', 'WIRELESS'}),
#  frozenset({'NEWYORK', 'WIRELESS'}),
#  frozenset({'WIRELESS', 'WIRELINES'}),
#  frozenset({'PENSELVANIYA', 'WIRELESS'}),
#  frozenset({'ALABAMA', 'WIRELESS'}),
#  frozenset({'MISSOURI', 'TEXAS'}),
#  frozenset({'NEWYORK', 'TEXAS'}),
#  frozenset({'TEXAS', 'WIRELINES'}),
#  frozenset({'PENSELVANIYA', 'TEXAS'}),
# ...

# %% [markdown]
# # Mining association rules from frequent item sets

# %% [markdown]
# Association rules are usually required to satisfy a user-specified minimum support and a user-specified minimum confidence at the same time. Association rule generation is usually split up into two separate steps: A minimum support threshold is applied to find all frequent itemsets in a database. A minimum confidence constraint is applied to these frequent itemsets in order to form rules.To find association rules, we first start with a frequent itemset. We know this set of items is unique, but we want to see if there is anything else we can get out of these items. One item or one set of items can imply another item. generateRules(), is the main command, which calls the other two. The generateRules() function takes three inputs: a list of frequent itemsets, a dictionary of support data for those itemsets, and a minimum confidence threshold. It’s going to generate a list of rules with confidence values that we can sort through later.

# %%
def generateRules(L, supportData, minConf=0.7):  #supportData is a dict coming from scanD
    bigRuleList = []
    for i in range(1, len(L)):#only get the sets with two or more items
        for freqSet in L[i]:
            H1 = [frozenset([item]) for item in freqSet]
            if (i > 1):
                rulesFromConseq(freqSet, H1, supportData, bigRuleList, minConf)
            else:
                calcConf(freqSet, H1, supportData, bigRuleList, minConf)
    return bigRuleList

# %% [markdown]
# calcConf() calculates the confidence of the rule and then find out the which rules meet the minimum confidence.

# %%
def calcConf(freqSet, H, supportData, brl, minConf=0.7):
    prunedH = [] #create new list to return
    for conseq in H:
        conf = supportData[freqSet]/supportData[freqSet-conseq] #calc confidence
        if conf >= minConf: 
            print (freqSet-conseq,'-->',conseq,'conf:',conf)
            brl.append((freqSet-conseq, conseq, conf))
            prunedH.append(conseq)
    return prunedH

# %% [markdown]
# rulesFromConseq() generates more association rules from our initial dataset. This takes a frequent itemset and H, which is a list of items that could be on the right-hand side of a rule.

# %%
def rulesFromConseq(freqSet, H, supportData, brl, minConf=0.7):
    m = len(H[0])
    if (len(freqSet) > (m + 1)): #try further merging
        Hmp1 = aprioriGen(H, m+1)#create Hm+1 new candidates
        Hmp1 = calcConf(freqSet, Hmp1, supportData, brl, minConf)
        if (len(Hmp1) > 1):    #need at least two sets to merge
            rulesFromConseq(freqSet, Hmp1, supportData, brl, minConf)

# %%
L,suppData= apriori(temp,minSupport=0.1)

# %%
rules= generateRules(L,suppData, minConf=0.1)
# Out:
# (frozenset(['NEWYORK']), '-->', frozenset(['WIRELESS']), 'conf:', 0.37837837837837834)
# (frozenset(['WIRELESS']), '-->', frozenset(['NEWYORK']), 'conf:', 0.32941176470588235)

# %% [markdown]
# I have taken only a small part of the dataset for which I have analyzed the above results.
#
# The above rules confidently says that in NEWYORK city wirless is more and there is more confidence to install more wireless over there and vice versa.

# %% [markdown]
# Citation: [1].vaish, piush. “Apriori Algorithm (Python 3.0).” A Data Analyst, Piush.vaish, 7 Aug. 2016, adataanalyst.com/machine-learning/apriori-algorithm-python-3-0/.
