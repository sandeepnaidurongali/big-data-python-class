# %% [markdown]
# ## Homework 3.1
#
# ### 3.1.a
# Load the data from: http://opendata.dc.gov/datasets that I have include in this github
# into a dataframe.  ( The file has been is available in directory ./data/ccp_current_csv.csv )

# %%
import pandas as pd
Sample= pd.read_csv("data\ccp_current_csv.csv")
Sample.head()
# Out:
#              STREET QUADRANT  FROMINTERSECTION              TOINTERSECTION  \
# 0           13th St       NW        Kennedy St               Longfellow St
# 1              S St       NW  North Capitol St                      3rd St
# 2  Rhode Island Ave       NE  Brentwood Rd (W)            Brentwood Rd (M)
# 3           Mill Rd       NW           27th St                  Cul De Sac
# 4  Rhode Island Ave       NE  Brentwood Rd (M)  14th St  Evarts St  Montan
#
#    NOOFBLOCKS                 WORKDESCRIPTION  YEARBUDGETED  PERCENTCOMPLETED  \
# 0           1  Pavement Resurface/restoration          2004               100
# 1           3                   Regular Cover          1999               100
# 2           1  Pavement Resurface/restoration          2004               100
# 3           1  Pavement Resurface/restoration          2004               100
# 4           2  Pavement Resurface/restoration          2005               100
#
#       STATUS  MILES      ...             YCOORD   LATITUDE  LONGITUDE  \
# 0  Completed   0.07      ...       143205.11981  38.956747 -77.029694
# 1  Completed   0.33      ...       138468.90256  38.914085 -77.012411
# 2  Completed   0.09      ...       139574.10659  38.924041 -76.987221
# 3  Completed   0.07      ...       138132.90198  38.911046 -77.054077
# 4  Completed   0.16      ...       139657.25318  38.924790 -76.985068
#
#            PROJECTNOTE                                        PROJECTNAME  \
# 0                  NaN                                             FedAid
# 1                  NaN                                                NaN
# 2                  NaN           Fedral Aid Citywide Pavement Restoration
# 3  POKA-2003-B-0048-JJ  Citywide Pavement Restoration Contract (Local ...
# 4                  NaN                                                NaN
#
#           PROJECTMGR  PROJECTID        TEAMREP                 EMAIL  \
# 0    Paul Stephenson       5834        O. Hill                   NaN
# 1                NaN       2467            NaN                   NaN
# 2  Mohamed Abdullahi       5486   Said Cherifi   said.cherifi@dc.gov
# 3    Maduabuchi Udeh       5796  Michael Jelen  Michael.Jelen@dc.gov
# 4                NaN       8237            NaN                   NaN
#
#    CONTACTPHONE
# 0  202-671-4591
# 1           NaN
# 2  202-671-4611
# 3  202-671-4542
# 4           NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 3.1.a  what is its shape and what does that mean?

# %%
Sample.shape
# Out:
# (465, 27)

# %%
Sample.mean()
# Out:
# NOOFBLOCKS               2.146237
# YEARBUDGETED          1956.759140
# PERCENTCOMPLETED       100.000000
# MILES                    0.193591
# XCOORD              399430.352561
# YCOORD              138503.369922
# LATITUDE                38.914389
# LONGITUDE              -77.006578
# PROJECTID             5637.784946
# dtype: float64

# %% [markdown]
# ## Homework 3.2
#  What are the number of rows in each 'QUADRANT' ?

# %% [markdown]
# Procedure 1

# %%
from scipy.stats import itemfreq
import numpy as np
A=np.array(Sample)
itemfreq(A[:,1])
# Out:
# C:\Users\Sandeep\Anaconda2\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `itemfreq` is deprecated!
# `itemfreq` is deprecated and will be removed in a future version. Use instead `np.unique(..., return_counts=True)`
#   after removing the cwd from sys.path.
# array([['BN', 12L],
#        ['NE', 163L],
#        ['NW', 195L],
#        ['SE', 84L],
#        ['SW', 11L]], dtype=object)

# %% [markdown]
# Procedure 2

# %%
Temp=np.unique(A[:,1])
BN=NE=NW=SE=SW = 0
print Temp
for x in range(len(A[:,1])):
    if A[x,1] == Temp[0]:
        BN = BN+1
    elif A[x,1] == Temp[1]:
        NE = NE+1
    elif A[x,1] == Temp[2]:
        NW = NW+1
    elif A[x,1] == Temp[3]:
        SE = SE+1
    else:
        SW=SW+1
print 'BN -->', BN  
print 'NE -->', NE
print 'NW -->', NW
print 'SE -->', SE
print 'SW -->', SW
# Out:
# ['BN' 'NE' 'NW' 'SE' 'SW']
# BN --> 12
# NE --> 163
# NW --> 195
# SE --> 84
# SW --> 11

# %% [markdown]
# ## Homework 3.3 - Array math demonstration
# For two arrarys
#
# a= [1,2,3,4]  type=float
#
# b= [5,6,7,8]  type=float
#
# Peform the following array operations using numpy
# ( show both operational use of numpy and functional (example addition operation => + vs addition function => numbpy.add() )
#
# ### 3.3.1 addition a+b

# %%
import numpy as np
a = np.asarray([1,2,3,4], dtype = float)
b=np.asarray([5,6,7,8], dtype = float)

# %%
np.add(a,b)
# Out:
# array([ 6.,  8., 10., 12.])

# %%
a+b
# Out:
# array([ 6.,  8., 10., 12.])

# %% [markdown]
# ### 3.3.2 subtraction a-b

# %%
np.subtract(a,b)
# Out:
# array([-4., -4., -4., -4.])

# %%
a-b
# Out:
# array([-4., -4., -4., -4.])

# %% [markdown]
# ### 3.3.3 multiplication a*b

# %%
np.multiply(a,b)
# Out:
# array([ 5., 12., 21., 32.])

# %%
list1=a*b
print list1
# Out:
# [ 5. 12. 21. 32.]

# %% [markdown]
# ### 3.3.4 divsion a/b

# %%
np.divide(a,b)
# Out:
# array([0.2       , 0.33333333, 0.42857143, 0.5       ])

# %%
a/b
# Out:
# array([0.2       , 0.33333333, 0.42857143, 0.5       ])

# %% [markdown]
# ### 3.3.5 modulo  a%b

# %%
np.mod(a,b)
# Out:
# array([1., 2., 3., 4.])

# %%
a%b
# Out:
# array([1., 2., 3., 4.])

# %% [markdown]
# ### 3.3.6 power  a^b

# %%
np.power(a,b)
# Out:
# array([1.0000e+00, 6.4000e+01, 2.1870e+03, 6.5536e+04])

# %%
a**b
# Out:
# array([1.0000e+00, 6.4000e+01, 2.1870e+03, 6.5536e+04])

# %% [markdown]
# ## Homework 3.4
# Find your own data and load it into a dataframe

# %%
import numpy as np
import pandas as pd
Own_data=pd.read_csv("data/googleplaystore.csv")
print Own_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play    15-Jan-18               2.0.0  4.0.3 and up
# 2               Art & Design     1-Aug-18               1.2.4  4.0.3 and up
# 3               Art & Design     8-Jun-18  Varies with device    4.2 and up
# 4    Art & Design;Creativity    20-Jun-18                 1.1    4.4 and up

# %%
A=np.array(Own_data)
print(A)
# Out:
# [['Photo Editor & Candy Camera & Grid & ScrapBook' 'ART_AND_DESIGN' 4.1
#   ... '7-Jan-18' '1.0.0' '4.0.3 and up']
#  ['Coloring book moana' 'ART_AND_DESIGN' 3.9 ... '15-Jan-18' '2.0.0'
#   '4.0.3 and up']
#  ['U Launcher Lite \xe2\x80\x93 FREE Live Cool Themes, Hide Apps'
#   'ART_AND_DESIGN' 4.7 ... '1-Aug-18' '1.2.4' '4.0.3 and up']
#  ...
#  ['ClearCareGo Caregiver' 'MEDICAL' 4.2 ... '25-Jul-18' '2.1.3'
#   '4.1 and up']
#  ['Pregnancy Calculator and Tracker app' 'MEDICAL' 4.8 ... '1-Jun-18'
#   '2.6.1' '4.1 and up']
#  ['All Mental disorders' 'MEDICAL' 4.5 ... '7-Jul-17' '1.1'
#   '4.0.3 and up']]

# %% [markdown]
# ## Homework 3.5
# Provide an interesting analysis of the data columns ( frequency or averages )

# %%
from scipy.stats import itemfreq
itemfreq(A[:,3])
# Out:
# C:\Users\Sandeep\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `itemfreq` is deprecated!
# `itemfreq` is deprecated and will be removed in a future version. Use instead `np.unique(..., return_counts=True)`
# array([[0L, 20L],
#        [1L, 8L],
#        [2L, 8L],
#        ...,
#        [56642847L, 1L],
#        [56646578L, 1L],
#        [69119316L, 2L]], dtype=object)

# %%
itemfreq(Own_data)
# Out:
# C:\Users\Sandeep\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `itemfreq` is deprecated!
# `itemfreq` is deprecated and will be removed in a future version. Use instead `np.unique(..., return_counts=True)`
#   """Entry point for launching an IPython kernel.
# array([[0L, 1L],
#        [nan, 1L],
#        [0L, 3L],
#        ...,
#        ['\xe4\xb9\x90\xe5\xb1\x8b\xe7\xbd\x91: Buying a house, selling a house, renting a house',
#         1L],
#        ['\xe6\xbc\xab\xe5\x92\x96 Comics - Manga,Novel and Stories', 1L],
#        ['\xf0\x9f\x94\xa5 Football Wallpapers 4K | Full HD Backgrounds \xf0\x9f\x98\x8d',
#         1L]], dtype=object)

# %%
np.unique(A[3,:])
# Out:
# array([4.5, 215644L, '0', '25M', '4.2 and up', '50,000,000+', '8-Jun-18',
#        'ART_AND_DESIGN', 'Art & Design', 'Free', 'Sketch - Draw & Paint',
#        'Teen', 'Varies with device'], dtype=object)

# %%
np.unique(Own_data)
# Out:
# array([0L, nan, 0L, ...,
#        '\xe4\xb9\x90\xe5\xb1\x8b\xe7\xbd\x91: Buying a house, selling a house, renting a house',
#        '\xe6\xbc\xab\xe5\x92\x96 Comics - Manga,Novel and Stories',
#        '\xf0\x9f\x94\xa5 Football Wallpapers 4K | Full HD Backgrounds \xf0\x9f\x98\x8d'],
#       dtype=object)

# %% [markdown]
# # Average

# %%
np.average(np.float64(A[:,3]))
# Out:
# 892974.3695931478

# %%
np.mean(A[:,3])
# Out:
# 892974.3695931478

# %%
print np.array_split(A,10)
# Out:
# [array([['Photo Editor & Candy Camera & Grid & ScrapBook',
#         'ART_AND_DESIGN', 4.1, ..., '7-Jan-18', '1.0.0', '4.0.3 and up'],
#        ['Coloring book moana', 'ART_AND_DESIGN', 3.9, ..., '15-Jan-18',
#         '2.0.0', '4.0.3 and up'],
#        ['U Launcher Lite \xe2\x80\x93 FREE Live Cool Themes, Hide Apps',
#         'ART_AND_DESIGN', 4.7, ..., '1-Aug-18', '1.2.4', '4.0.3 and up'],
#        ...,
#        ['Tiny Scanner - PDF Scanner App', 'BUSINESS', 4.7, ...,
#         '30-May-17', '1.2.6', '3.0 and up'],
#        ['Fast Scanner : Free PDF Scan', 'BUSINESS', 4.5, ...,
#         '11-Jul-18', '3.9.2', '4.1 and up'],
#        ['Mobile Doc Scanner (MDScan) Lite', 'BUSINESS', 4.2, ...,
#         '2-Aug-18', '3.4.49', '4.1 and up']], dtype=object), array([['TurboScan: scan documents and receipts in PDF', 'BUSINESS', 4.7,
#         ..., '25-Mar-18', '1.5.2', '4.0 and up'],
#        ['Tiny Scanner Pro: PDF Doc Scan', 'BUSINESS', 4.8, ...,
#         '11-Apr-17', '3.4.6', '3.0 and up'],
#        ['Box', 'BUSINESS', 4.2, ..., '31-Jul-18', 'Varies with device',
#         'Varies with device'],
#        ...,
#        ['imo free video calls and chat', 'COMMUNICATION', 4.3, ...,
#         '8-Jun-18', '9.8.000000010501', '4.0 and up'],
#        ['free video calls and chat', 'COMMUNICATION', 4.2, ...,
#         '19-Jul-18', '7.3(800241)', '4.4 and up'],
#        ['Viber Messenger', 'COMMUNICATION', 4.3, ..., '18-Jul-18',
#         'Varies with device', 'Varies with device']], dtype=object), array([['Skype - free IM & video calls', 'COMMUNICATION', 4.1, ...,
#         '3-Aug-18', 'Varies with device', 'Varies with device'],
#        ['WeChat', 'COMMUNICATION', 4.2, ..., '31-Jul-18',
#         'Varies with device', 'Varies with device'],
#        ['Vonage Mobile\xc2\xae Call Video Text', 'COMMUNICATION', 4.1,
#         ..., '28-Sep-16', '2.9.8', '2.3.3 and up'],
#        ...,
#        ['Duolingo: Learn Languages Free', 'EDUCATION', 4.7, ...,
#         '1-Aug-18', 'Varies with device', 'Varies with device'],
#        ['TED', 'EDUCATION', 4.6, ..., '27-Jul-18', '3.2.5', '4.1 and up'],
#        ['English Communication - Learn English for Chinese (Learn English for Chinese)',
#         'EDUCATION', 4.7, ..., '29-Dec-17', '3.1', '4.0 and up']],
#       dtype=object), array([['Khan Academy', 'EDUCATION', 4.6, ..., '27-Jul-18', '5.0.0',
#         '4.1 and up'],
#        ['Learn English with Wlingua', 'EDUCATION', 4.7, ..., '2-May-18',
#         '1.94.9', '4.0 and up'],
#        ['Ai La Trieu Phu - ALTP Free', 'EDUCATION', nan, ...,
#         '23-Jul-18', '1.5', '4.0 and up'],
#        ...,
#        ['Crunchyroll - Everything Anime', 'ENTERTAINMENT', 3.7, ...,
#         '5-Mar-18', 'Varies with device', 'Varies with device'],
#        ['STARZ', 'ENTERTAINMENT', 4.3, ..., '20-Jun-18',
#         'Varies with device', 'Varies with device'],
#        ['Crackle - Free TV & Movies', 'ENTERTAINMENT', 3.7, ...,
#         '12-Apr-18', 'Varies with device', 'Varies with device']],
#       dtype=object), array([['CBS - Full Episodes & Live TV', 'ENTERTAINMENT', 3.8, ...,
#         '20-Jul-18', '4.8.6', '4.1 and up'],
#        ['Nick', 'ENTERTAINMENT', 4.2, ..., '24-Jan-18', '2.0.8',
#         '4.4 and up'],
#        ['Hulu: Stream TV, Movies & more', 'ENTERTAINMENT', 4.0, ...,
#         '3-Aug-18', 'Varies with device', '5.0 and up'],
#        ...,
#        ['Discover Mobile', 'FINANCE', 4.6, ..., '23-Jul-18', '9.7.0',
#         '4.1 and up'],
#        ['Wells Fargo Mobile', 'FINANCE', 4.4, ..., '31-Jul-18',
#         '6.8.0.109', '5.0 and up'],
#        ['Capital One\xc2\xae Mobile', 'FINANCE', 4.6, ..., '1-Aug-18',
#         '5.38.1', '5.0 and up']], dtype=object), array([['Amex Mobile', 'FINANCE', 4.3, ..., '3-Aug-18', '6.7.0',
#         '5.0 and up'],
#        ['Citi Mobile\xc2\xae', 'FINANCE', 4.0, ..., '31-Jul-18', '9.9.0',
#         '4.4 and up'],
#        ['Navy Federal Credit Union', 'FINANCE', 4.4, ..., '9-Jul-18',
#         '5.16.2', '4.1 and up'],
#        ...,
#        ['MealLogger-Photo Food Journal', 'HEALTH_AND_FITNESS', 3.5, ...,
#         '23-Aug-17', '4.6.2', '4.0.3 and up'],
#        ['Health and Nutrition Guide', 'HEALTH_AND_FITNESS', 4.3, ...,
#         '15-Jul-18', '3.3', '4.0 and up'],
#        ['Calorie Counter & Diet Tracker', 'HEALTH_AND_FITNESS', 4.5, ...,
#         '22-Mar-18', 'Varies with device', 'Varies with device']],
#       dtype=object), array([['Food Calorie Calculator', 'HEALTH_AND_FITNESS', 4.2, ...,
#         '29-Jan-18', '10.2.0', '4.0 and up'],
#        ['Calorie Counter - MyFitnessPal', 'HEALTH_AND_FITNESS', 4.6, ...,
#         '31-Jul-18', 'Varies with device', 'Varies with device'],
#        ['Lose It! - Calorie Counter', 'HEALTH_AND_FITNESS', 4.4, ...,
#         '3-Aug-18', 'Varies with device', 'Varies with device'],
#        ...,
#        ['Zara', 'LIFESTYLE', 4.3, ..., '30-Jul-18', '4.1.0',
#         '4.1 and up'],
#        ['Real Estate by Movoto', 'LIFESTYLE', 4.4, ..., '20-Feb-18',
#         '6.1', '4.0.3 and up'],
#        ['Etta Homes', 'LIFESTYLE', 4.2, ..., '26-Jul-18', '9.1.0',
#         '5.0 and up']], dtype=object), array([['Houlihan Lawrence', 'LIFESTYLE', 4.4, ..., '12-Oct-17', '3.9.5',
#         '4.2 and up'],
#        ['Home Scouting\xc2\xae MLS Mobile', 'LIFESTYLE', 4.3, ...,
#         '27-Sep-16', '2.2.6', '2.2 and up'],
#        ['Housing-Real Estate & Property', 'LIFESTYLE', 4.1, ...,
#         '13-Jul-18', '12.1.0', '4.1 and up'],
#        ...,
#        ['Lords Mobile: Battle of the Empires - Strategy RPG', 'GAME',
#         4.4, ..., '26-Jul-18', '1.76', '2.3 and up'],
#        ['War and Order', 'GAME', 4.3, ..., '18-Jul-18', '1.1.8',
#         '4.0.3 and up'],
#        ['Dungeon Hunter Champions: Epic Online Action RPG', 'GAME', 4.2,
#         ..., '26-Jul-18', '1.1.40', '4.0.3 and up']], dtype=object), array([['Candy Crush Saga', 'GAME', 4.4, ..., '5-Jul-18', '1.129.0.2',
#         '4.1 and up'],
#        ['ROBLOX', 'GAME', 4.5, ..., '31-Jul-18', '2.347.225742',
#         '4.1 and up'],
#        ['8 Ball Pool', 'GAME', 4.5, ..., '31-Jul-18', '4.0.0',
#         '4.0.3 and up'],
#        ...,
#        ['Cars: Lightning League', 'FAMILY', 4.5, ..., '21-May-18', '1.6',
#         '4.0.3 and up'],
#        ['Little Panda Run', 'FAMILY', 4.2, ..., '20-Jun-18',
#         '8.25.10.00', '4.0.3 and up'],
#        ["Snoopy's Town Tale - City Building Simulator", 'FAMILY', 4.2,
#         ..., '30-Jul-18', '3.2.4', '4.4 and up']], dtype=object), array([['Car Racing game for Kids - Beepzz Dogs \xf0\x9f\x90\x95',
#         'FAMILY', 4.4, ..., '13-Jun-18', '1.1.1', '4.2 and up'],
#        ['Pony Friends \xf0\x9f\xa6\x84 - Beepzz racing game for kids',
#         'FAMILY', 4.5, ..., '13-Jun-18', '1.4.3', '4.2 and up'],
#        ['LEGO\xc2\xae Juniors Create & Cruise', 'FAMILY', 4.1, ...,
#         '19-Jan-18', '6.7.5222', '4.1 and up'],
#        ...,
#        ['ClearCareGo Caregiver', 'MEDICAL', 4.2, ..., '25-Jul-18',
#         '2.1.3', '4.1 and up'],
#        ['Pregnancy Calculator and Tracker app', 'MEDICAL', 4.8, ...,
#         '1-Jun-18', '2.6.1', '4.1 and up'],
#        ['All Mental disorders', 'MEDICAL', 4.5, ..., '7-Jul-17', '1.1',
#         '4.0.3 and up']], dtype=object)]

# %%
Own_data.mean()
# Out:
# Rating          4.294086
# Reviews    892974.369593
# dtype: float64
